# %%
import cv2 as cv
import numpy as np

cam = cv.VideoCapture(0)

def list_populate(x) :
    list = []
    for x in range(x) :
        list.append(-1)
    return list

l_old = list_populate(300)

def func(list,gray,i) :
    if list[i] == -1 :
        list[i] = gray[i,i]
    else:
        if -10 < list[i]-gray[i,i] < 5 : 
            for j in range(i) :
                gray[i,j] = 0
        else :
            list[i] = gray[i,i]
    

while True:
    
    _,frame = cam.read()
    print(cam.get(cv.CAP_PROP_FPS))
    gray = cv.cvtColor(frame,cv.COLOR_BGR2GRAY)
    print(gray.shape)
    for x in range(300):
        func(l_old,gray,x)
    
    cv.imshow("gray",gray)

    if cv.waitKey(1) & 0xFF == ord("q") :
        break
    
cam.release()
cv.destroyAllWindows()
# Out:
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# /home/jashan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: overflow encountered in ubyte_scalars
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
# 30.0
# (480, 640)
