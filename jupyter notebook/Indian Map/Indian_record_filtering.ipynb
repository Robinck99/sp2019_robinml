# %%
import pandas as pd

d_state = {'rajasthan': 0, 'madhya pradesh': 1, 'maharashtra': 2, 'jammu & kashmir': 3, 'uttar pradesh': 4, 'andhra pradesh': 5, 'gujarat': 6, 'karnataka': 7, 'orissa': 8, 'chhattisgarh': 9, 'tamil nadu': 10, 'bihar': 11, 'arunachal pradesh': 12, 'assam': 13, 'jharkhand': 14, 'west bengal': 15, 'himachal pradesh': 16, 'uttarakhand': 17, 'punjab': 18, 'haryana': 19, 'kerala': 20, 'manipur': 21, 'meghalaya': 22, 'mizoram': 23, 'nagaland': 24, 'tripura': 25, 'sikkim': 26, 'goa': 27, 'delhi': 28}

database = pd.read_csv('Sub_Division_IMD_2017.csv')
database

# convert to lower scale
def convert_to_lower(val) :
    return val.lower()

database.SUBDIVISION = database.SUBDIVISION.apply(convert_to_lower).copy()
database
# Out:
#                     SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY  \
# 0     andaman & nicobar islands  1901   49.2   87.1   29.2    2.3  528.8
# 1     andaman & nicobar islands  1902    0.0  159.8   12.2    0.0  446.1
# 2     andaman & nicobar islands  1903   12.7  144.0    0.0    1.0  235.1
# 3     andaman & nicobar islands  1904    9.4   14.7    0.0  202.4  304.5
# 4     andaman & nicobar islands  1905    1.3    0.0    3.3   26.9  279.5
# 5     andaman & nicobar islands  1906   36.6    0.0    0.0    0.0  556.1
# 6     andaman & nicobar islands  1907  110.7    0.0  113.3   21.6  616.3
# 7     andaman & nicobar islands  1908   20.9   85.1    0.0   29.0  562.0
# 8     andaman & nicobar islands  1910   26.6   22.7  206.3   89.3  224.5
# 9     andaman & nicobar islands  1911    0.0    8.4    0.0  122.5  327.3
# 10    andaman & nicobar islands  1912  583.7    0.8    0.0   21.9  140.7
# 11    andaman & nicobar islands  1913   84.8    0.5    1.3    2.5  190.7
# ...

# %%
l = list(database.YEAR.unique())
l

import os

path = os.getcwd()
print(path)
for year in l :
    data = database[database.YEAR == int(year)].copy()
    data.reset_index(drop=True, inplace= True)
    data.to_csv(path + '/year_record/record_' + str(year) + '.csv')
# Out:
# /Users/jashan-ck/Downloads/GIT/Summer_Project/jupyter notebook/Indian Map
